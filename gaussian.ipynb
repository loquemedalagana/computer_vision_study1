# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

image = cv2.imread('images/_X1A0364-Enhanced-NR.jpg', cv2.IMREAD_GRAYSCALE)
mean = 0 # average
sigma = 1 # 표준편차

gaussian_noise = np.random.normal(mean, sigma, image.shape).astype('uint8')
noisy_image = cv2.add(image, gaussian_noise)

plt.imshow(noisy_image, cmap='gray')
plt.title('Noisy Image')
plt.axis('off')

plt.show()

# %%
sigma_values = [1, 5, 10]
denoised_images = []

for sigma in sigma_values:
    denoised = cv2.GaussianBlur(noisy_image, (0, 0), sigma)
    denoised_images.append(denoised)

fig, axes = plt.subplots(1, 4, figsize=(20, 10))
axes[0].imshow(noisy_image, cmap='gray')
axes[0].set_title('noisy_image')
axes[0].axis('off')

for ax, img, sigma in zip(axes[1:], denoised_images, sigma_values):
    ax.imshow(img, cmap='gray')
    ax.set_title(f'Denoised (o={sigma})')
    ax.axis('off')

plt.tight_layout()
plt.show()
